# %% [markdown]
# Marcin Piątek

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

def funkcja(x):
  return x*x+5


x = np.linspace(-1, 1)

y = funkcja(x)
plt.figure(1)
plt.plot(x,y, label="funkcja")
plt.title("x^2+5")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
x = np.linspace(-6, 6)

y = funkcja(x)
plt.figure(1)
plt.plot(x,y, label="funkcja")
plt.title("x^2+5")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
x = np.linspace(0, 5)

y = funkcja(x)
plt.figure(1)
plt.plot(x,y, label="funkcja")
plt.title("x^2+5")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
import pandas as pd
data = np.array([['Marcin', 'Ala', 'Ola'], ['Nowak', 'Kowal', 'Mak'], [7, 8, 9,], ['m', 'k', 'k']]) 
columns=['name', 'surname', 'age', 'sex']
df2 = pd.DataFrame(data, columns)
df2
# Out:
#               0      1    2
# name     Marcin    Ala  Ola
# surname   Nowak  Kowal  Mak
# age           7      8    9
# sex           m      k    k
